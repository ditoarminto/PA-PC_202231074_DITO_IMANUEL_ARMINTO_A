# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Menampung gambar pada variabel lain
original_image = cv2.imread("dito.jpg")

# Konversi RGB ke BGR
original_image_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

# %%
# Menampilkan gambar sebagai panduan untuk proses selanjutnya
plt.figure(figsize=(8, 6))
plt.imshow(image_rgb)
plt.title("Original Image")
plt.axis('on')  # Tampilkan axis untuk menunjukkan koordinat pixel
plt.show()

# %%
# Rotasi gambar sebanyak 45 derajat
(h, w) = original_image.shape[:2]
center = (w // 2, h // 2)
M = cv2.getRotationMatrix2D(center, 45, 1.0)
rotated_image = cv2.warpAffine(original_image_rgb, M, (w, h))

# Rezise gambar menjadi 95 * 127
resized_image = cv2.resize(original_image_rgb, (95, 127))

# Crop gambar dengan ukuran posisi awal 1500 dan 1000 ke posisi akhir 4000 dan 2000
cropped_image = original_image_rgb[1500:4000, 1000:2000]

# Flip gambar secara horizontal
flipped_image = cv2.flip(original_image_rgb, 1)

# Translate gambar atau shifting gambar
tx, ty = 50, 50
M_translate = np.float32([[1, 0, tx], [0, 1, ty]])
translated_image = cv2.warpAffine(original_image_rgb, M_translate, (w, h))

# %%
# tampilkan gambar
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# List gambar dan titlenya
images = [original_image_rgb, rotated_image, resized_image, cropped_image, flipped_image, translated_image]
titles = ["Citra Asli", "Citra Rotasi", "Citra Rezise", "Citra Crop", "Citra Flip", "Citra Translate"]

# Plot gambarnya
for ax, img, title in zip(axes.flatten(), images, titles):
    ax.imshow(img)
    ax.set_title(title)
    ax.axis('off')

plt.tight_layout()
plt.show()
